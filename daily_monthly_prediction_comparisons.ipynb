# %%
# Load dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split

# %%
parameter_list = [
    'Type',
    'SVM',
    'C',
    'Gamma',
    'Epsilon',
    'Score',
    'RMSE',
    'OLS Score',
    'OLS RMSE'
]
dpA_params = [
    'Daily',
    'RBF',
    10,
    0.1,
    0.1,
    0.3459,
    round((0.000379**0.5),4),
    0.2150,
    round((0.000455**0.5),4)
]
dpB_params = [
    'Daily',
    'RBF',
    10,
    0.1,
    0.01,
    0.8023,
    round((0.0475**0.5),4),
    0.6445,
    round((0.0854**0.5),4)
]
dpC_params = [
    'Daily',
    'RBF',
    5,
    0.1,
    0.1,
    0.4411,
    round((0.0000000671**0.5),4),
    0.1814,
    round((0.0000000982**0.5),4)
]
dpD_params = [
    'Daily',
    'RBF',
    10,
    0.1,
    0.1,
    0.5886,
    round((0.00000656**0.5),4),
    0.1577,
    round((0.000013**0.5),4)
]
mpA_params = [
    'Monthly',
    'Linear',
    5,
    0.001,
    0,
    0.8360,
    round((0.000171**0.5),4),
    0.8358,
    round((0.000171**0.5),4)
]
mpB_params = [
    'Monthly',
    'RBF',
    5,
    0.1,
    0.1,
    0.8305,
    round((0.0427**0.5),4),
    0.7513,
    round((0.0626**0.5),4)
]
mpC_params = [
    'Monthly',
    'NONE',
    'NONE',
    'NONE',
    'NONE',
    'NONE',
    'NONE',
    'NONE',
    'NONE'
]
mpD_params = [
    'Monthly',
    'RBF',
    1,
    0.1,
    0.01,
    0.5655,
    round((0.0000062**0.5),4),
    0.2011,
    round((0.00001**0.5),4)
]

# %%
regression_dict = {
    'pA_D': dpA_params,
    'pB_D': dpB_params,
    'pC_D': dpC_params,
    'pD_D': dpD_params,
    'pA_M': mpA_params,
    'pB_M': mpB_params,
    'pC_M': mpC_params,
    'pD_M': mpD_params
}

# %%
regressions = pd.DataFrame(regression_dict,index=parameter_list)
regressions
# Out:
#              pA_D    pB_D    pC_D    pD_D     pA_M     pB_M     pC_M     pD_M
# Type        Daily   Daily   Daily   Daily  Monthly  Monthly  Monthly  Monthly
# SVM           RBF     RBF     RBF     RBF   Linear      RBF     NONE      RBF
# C              10      10       5      10        5        5     NONE        1
# Gamma         0.1     0.1     0.1     0.1    0.001      0.1     NONE      0.1
# Epsilon       0.1    0.01     0.1     0.1        0      0.1     NONE     0.01
# Score      0.3459  0.8023  0.4411  0.5886    0.836   0.8305     NONE   0.5655
# RMSE       0.0195  0.2179  0.0003  0.0026   0.0131   0.2066     NONE   0.0025
# OLS Score   0.215  0.6445  0.1814  0.1577   0.8358   0.7513     NONE   0.2011
# OLS RMSE   0.0213  0.2922  0.0003  0.0036   0.0131   0.2502     NONE   0.0032

# %% [markdown]
# Based on the table above, monthly regressions have significantly better scores and lower MSE values than their daily counterparts. This, combined with the complications of running projections on a daily, rather than monthly, basis is why the remainder of the project will only focus on the monthly regressions.
#
# Note that there is no pC monthly model; there were not enough data points to justify a model as that contaminant did not start getting checked for until mid 2017. Having accurate models for pA, pB, and pD is more than was originally expected

# %%
regressions.to_csv('Resources/daily_monthly_comparison.csv',index=False)
