# %%
# Load dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split

# %%
parameter_list = [
    'Type',
    'SVM',
    'C',
    'Gamma',
    'Epsilon',
    'Score',
    'RMSE',
    'OLS Score',
    'OLS RMSE'
]
dpA_params = [
    'Daily',
    'RBF',
    10,
    0.1,
    0.1,
    0.2878,
    (0.00052**0.5),
    0.1729,
    (0.000603**0.5)
]
dpB_params = [
    'Daily',
    'RBF',
    10,
    0.1,
    0.1,
    0.7639,
    (0.0608**0.5),
    0.6162,
    (0.0988**0.5)
]
dpC_params = [
    'Daily',
    'RBF',
    5,
    0.1,
    0.1,
    0.3146,
    (0.00000013**0.5),
    0.1211,
    (0.00000016**0.5)
]
dpD_params = [
    'Daily',
    'RBF',
    10,
    0.1,
    0.1,
    0.4970,
    (0.0000098**0.5),
    0.1281,
    (0.000017**0.5)
]
mpA_params = [
    'Monthly',
    'Linear',
    5,
    0.001,
    0,
    0.8360,
    (0.000171**0.5),
    0.8354,
    (0.000171**0.5)
]
mpB_params = [
    'Monthly',
    'RBF',
    5,
    0.1,
    0.1,
    0.8305,
    (0.0427**0.5),
    0.7513,
    (0.0626**0.5)
]
mpC_params = [
    'Monthly',
    'NONE',
    'NONE',
    'NONE',
    'NONE',
    'NONE',
    'NONE',
    'NONE',
    'NONE'
]
mpD_params = [
    'Monthly',
    'RBF',
    1,
    0.1,
    0.01,
    0.5655,
    (0.0000062**0.5),
    0.2011,
    (0.00001**0.5)
]

# %%
regression_dict = {
    'pA_D': dpA_params,
    'pB_D': dpB_params,
    'pC_D': dpC_params,
    'pD_D': dpD_params,
    'pA_M': mpA_params,
    'pB_M': mpB_params,
    'pC_M': mpC_params,
    'pD_M': mpD_params
}

# %%
regressions = pd.DataFrame(regression_dict,index=parameter_list)
regressions
# Out:
#                 pA_D      pB_D         pC_D        pD_D       pA_M     pB_M  \
# Type           Daily     Daily        Daily       Daily    Monthly  Monthly
# SVM              RBF       RBF          RBF         RBF     Linear      RBF
# C                 10        10            5          10          5        5
# Gamma            0.1       0.1          0.1         0.1      0.001      0.1
# Epsilon          0.1       0.1          0.1         0.1          0      0.1
# Score         0.2878    0.7639       0.3146       0.497      0.836   0.8305
# RMSE       0.0228035  0.246577  0.000360555   0.0031305  0.0130767  0.20664
# OLS Score     0.1729    0.6162       0.1211      0.1281     0.8354   0.7513
# OLS RMSE   0.0245561  0.314325       0.0004  0.00412311  0.0130767   0.2502
#
#               pC_M        pD_M
# Type       Monthly     Monthly
# SVM           NONE         RBF
# C             NONE           1
# Gamma         NONE         0.1
# Epsilon       NONE        0.01
# Score         NONE      0.5655
# RMSE          NONE  0.00248998
# OLS Score     NONE      0.2011
# OLS RMSE      NONE  0.00316228

# %% [markdown]
# Based on the table above, monthly regressions have significantly better scores and lower MSE values than their daily counterparts. This, combined with the complications of running projections on a daily, rather than monthly, basis is why the remainder of the project will only focus on the monthly regressions.
#
# Note that there is no pC monthly model; there were not enough data points to justify a model as that contaminant did not start getting checked for until mid 2017. Having accurate models for pA, pB, and pD is more than was originally expected

# %%
regressions.to_csv('Resources/daily_monthly_comparison.csv')
